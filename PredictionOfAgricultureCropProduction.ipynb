# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from glob import glob
import os

# %% [markdown]
# Data Cleaning

# %%
print(os.listdir())
# Out:
# ['.config', 'datafile_1.csv', 'merged.csv', 'mr', 'datafile_2.csv', 'datafile_0.csv', 'datafile_3.csv', 'mer', 'datafile_4.csv', 'sample_data']

# %%
df_0=pd.read_csv("datafile_0.csv")
df_1=pd.read_csv("datafile_1.csv")
df_2=pd.read_csv("datafile_2.csv")
df_3=pd.read_csv("datafile_3.csv")
df_4=pd.read_csv("datafile_4.csv")

# %% [markdown]
# step1: NaN values

# %%
df_0
# Out:
#                    Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0                  Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1                 Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2        Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3                Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4           Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
# 5                Fruits    100.0     99.0     99.0     98.0    102.0    104.0
# 6                  Milk    100.0     97.0     98.0     98.0     98.0    112.0
# 7   Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# 8              Oilseeds    100.0     86.0     85.0     97.0    104.0    103.0
# 9            Sugarcane     100.0     96.0     91.0     87.0     80.0     81.0
# 10               Fibers    100.0     92.0     91.0     96.0    109.0    107.0
# ...

# %%
df_0.isnull().sum()
# Out:
# Crop       1
# 2004-05    1
# 2005-06    1
# 2006-07    1
# 2007-08    1
# 2008-09    1
# 2009-10    1
# 2010-11    1
# 2011-12    1
# dtype: int64

# %%
df_0.isnull().any()
# Out:
# Crop       True
# 2004-05    True
# 2005-06    True
# 2006-07    True
# 2007-08    True
# 2008-09    True
# 2009-10    True
# 2010-11    True
# 2011-12    True
# dtype: bool

# %%
sns.heatmap(df_0.isnull(),yticklabels=False,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# step2 : removing null values

# %%
df_0=df_0.dropna(how='all')

# %%
df_0
# Out:
#                    Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0                  Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1                 Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2        Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3                Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4           Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
# 5                Fruits    100.0     99.0     99.0     98.0    102.0    104.0
# 6                  Milk    100.0     97.0     98.0     98.0     98.0    112.0
# 7   Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# 8              Oilseeds    100.0     86.0     85.0     97.0    104.0    103.0
# 9            Sugarcane     100.0     96.0     91.0     87.0     80.0     81.0
# 10               Fibers    100.0     92.0     91.0     96.0    109.0    107.0
# ...

# %%
df_1
# Out:
#                     Crop           State  \
# 0                  ARHAR   Uttar Pradesh
# 1                  ARHAR       Karnataka
# 2                  ARHAR         Gujarat
# 3                  ARHAR  Andhra Pradesh
# 4                  ARHAR     Maharashtra
# 5                 COTTON     Maharashtra
# 6                 COTTON          Punjab
# 7                 COTTON  Andhra Pradesh
# 8                 COTTON         Gujarat
# 9                 COTTON         Haryana
# 10                  GRAM       Rajasthan
# 11                  GRAM  Madhya Pradesh
# 12                  GRAM   Uttar Pradesh
# 13                  GRAM     Maharashtra
# 14                  GRAM  Andhra Pradesh
# 15             GROUNDNUT       Karnataka
# 16             GROUNDNUT  Andhra Pradesh
# 17             GROUNDNUT      Tamil Nadu
# 18             GROUNDNUT         Gujarat
# 19             GROUNDNUT     Maharashtra
# 20                 MAIZE           Bihar
# 21                 MAIZE       Karnataka
# ...

# %%
df_1.isnull().sum()
# Out:
# Crop                                     0
# State                                    0
# Cost of Cultivation (`/Hectare) A2+FL    0
# Cost of Cultivation (`/Hectare) C2       0
# Cost of Production (`/Quintal) C2        0
# Yield (Quintal/ Hectare)                 0
# dtype: int64

# %%
df_2
# Out:
#             Crop               Production 2006-07  Production 2007-08  \
# 0            Total Foodgrains               158.8               168.6
# 1                        Rice               200.8               207.9
# 2                       Wheat               131.6               136.4
# 3                       Jowar               124.3               137.8
# 4                       Bajra               136.4               161.5
# 5                       Maize               198.8               249.6
# 6                        Ragi                56.1                83.6
# 7               Small millets                53.9                61.9
# 8                      Barley                88.1                79.3
# 9              Coarse Cereals               138.5               166.4
# 10                    Cereals               164.1               174.6
# 11                       Gram               140.6               127.6
# ...

# %%
df_2.isnull().sum()
# Out:
# Crop                  0
# Production 2006-07    0
# Production 2007-08    0
# Production 2008-09    0
# Production 2009-10    0
# Production 2010-11    0
# Area 2006-07          0
# Area 2007-08          0
# Area 2008-09          0
# Area 2009-10          0
# Area 2010-11          0
# Yield 2006-07         0
# Yield 2007-08         0
# Yield 2008-09         0
# Yield 2009-10         0
# Yield 2010-11         0
# dtype: int64

# %%
df_3
# Out:
#            Crop                     Variety Season/ duration in days  \
# 0         Paddy  Chinsurah Rice (IET 19140)                   Medium
# 1         Paddy              (CNI 383-5-11)                      NaN
# 2         Paddy         IGKVR-1 (IET 19569)                Mid-early
# 3         Paddy         IGKVR-2 (IET 19795)                   Medium
# 4         Paddy        CR Dhan 401 (REETA)                   145-150
# ..          ...                         ...                      ...
# 73        Mesta            SHRESTHA (JRM-5)                        -
# 74       Cotton                      CNH012                      165
# 75       Cotton           CICR-3 (CISA 614)                      150
# 76       Cotton                   VBCH 2231                      NaN
# 77  Desi Cotton                     FDK 124                      NaN
#
#                                      Recommended Zone  Unnamed: 4
# 0   Andhra Pradesh, Tamil Nadu, Gujarat, Orissa, a...         NaN
# ...

# %%
df_3.isnull().sum()
# Out:
# Crop                         0
# Variety                      0
# Season/ duration in days    28
# Recommended Zone             1
# Unnamed: 4                  78
# dtype: int64

# %%
df_3.isnull().any()
# Out:
# Crop                        False
# Variety                     False
# Season/ duration in days     True
# Recommended Zone             True
# Unnamed: 4                   True
# dtype: bool

# %%
sns.heatmap(df_3.isnull(),yticklabels=False,annot=True)
# Out:
# <Axes: >

# %%
df_3.fillna(0)
# Out:
#            Crop                     Variety Season/ duration in days  \
# 0         Paddy  Chinsurah Rice (IET 19140)                   Medium
# 1         Paddy              (CNI 383-5-11)                        0
# 2         Paddy         IGKVR-1 (IET 19569)                Mid-early
# 3         Paddy         IGKVR-2 (IET 19795)                   Medium
# 4         Paddy        CR Dhan 401 (REETA)                   145-150
# ..          ...                         ...                      ...
# 73        Mesta            SHRESTHA (JRM-5)                        -
# 74       Cotton                      CNH012                      165
# 75       Cotton           CICR-3 (CISA 614)                      150
# 76       Cotton                   VBCH 2231                        0
# 77  Desi Cotton                     FDK 124                        0
#
#                                      Recommended Zone  Unnamed: 4
# 0   Andhra Pradesh, Tamil Nadu, Gujarat, Orissa, a...         0.0
# ...

# %%
df_3.fillna(method='ffill')
# Out:
#            Crop                     Variety Season/ duration in days  \
# 0         Paddy  Chinsurah Rice (IET 19140)                   Medium
# 1         Paddy              (CNI 383-5-11)                   Medium
# 2         Paddy         IGKVR-1 (IET 19569)                Mid-early
# 3         Paddy         IGKVR-2 (IET 19795)                   Medium
# 4         Paddy        CR Dhan 401 (REETA)                   145-150
# ..          ...                         ...                      ...
# 73        Mesta            SHRESTHA (JRM-5)                        -
# 74       Cotton                      CNH012                      165
# 75       Cotton           CICR-3 (CISA 614)                      150
# 76       Cotton                   VBCH 2231                      150
# 77  Desi Cotton                     FDK 124                      150
#
#                                      Recommended Zone  Unnamed: 4
# 0   Andhra Pradesh, Tamil Nadu, Gujarat, Orissa, a...         NaN
# ...

# %%
df_3=df_3.dropna(axis=1,how='all')

# %%
df_3=df_3.fillna(method='ffill')

# %%
df_3
# Out:
#            Crop                     Variety Season/ duration in days  \
# 0         Paddy  Chinsurah Rice (IET 19140)                   Medium
# 1         Paddy              (CNI 383-5-11)                   Medium
# 2         Paddy         IGKVR-1 (IET 19569)                Mid-early
# 3         Paddy         IGKVR-2 (IET 19795)                   Medium
# 4         Paddy        CR Dhan 401 (REETA)                   145-150
# ..          ...                         ...                      ...
# 73        Mesta            SHRESTHA (JRM-5)                        -
# 74       Cotton                      CNH012                      165
# 75       Cotton           CICR-3 (CISA 614)                      150
# 76       Cotton                   VBCH 2231                      150
# 77  Desi Cotton                     FDK 124                      150
#
#                                      Recommended Zone
# 0   Andhra Pradesh, Tamil Nadu, Gujarat, Orissa, a...
# ...

# %%
df_4
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit   3-1993   3-1994   3-1995  \
# 0    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 1    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 2    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# ...

# %%
df_4.isnull().sum()
# Out:
# Particulars      0
# Frequency        0
# Unit             0
#  3-1993        426
#  3-1994        425
#  3-1995        425
#  3-1996        423
#  3-1997        419
#  3-1998        419
#  3-1999        418
#  3-2000        409
#  3-2001        407
#  3-2002        393
#  3-2003        301
#  3-2004         68
#  3-2005          4
#  3-2006          6
#  3-2007         11
#  3-2008         12
#  3-2009         11
#  3-2010         26
#  3-2011         25
#  3-2012         41
#  3-2013        131
#  3-2014        366
# dtype: int64

# %%
df_4=df_4.fillna(method='ffill')

# %%
df_4=df_4.fillna(method='bfill')

# %%
df_4=df_4.interpolate()

# %%
df_4
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit   3-1993   3-1994   3-1995  \
# 0    Annual, Ending mar Of Each Year  Ton mn      0.0      0.0      0.0
# 1    Annual, Ending mar Of Each Year  Ton mn      0.0      0.0      0.0
# 2    Annual, Ending mar Of Each Year  Ton mn      0.0      0.0      0.0
# ...

# %%
df_1.head()
df_1.tail()
# Out:
#          Crop           State  Cost of Cultivation (`/Hectare) A2+FL  \
# 44  SUGARCANE      Tamil Nadu                               66335.06
# 45      WHEAT  Madhya Pradesh                               12464.40
# 46      WHEAT          Punjab                               17945.58
# 47      WHEAT   Uttar Pradesh                               18979.38
# 48      WHEAT       Rajasthan                               19119.08
#
#     Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 44                            89025.27                              85.79
# 45                            22489.75                             810.25
# 46                            35423.48                             804.80
# 47                            31902.74                             769.84
# 48                            29876.36                             683.58
#
#     Yield (Quintal/ Hectare)
# 44                    1015.45
# 45                      23.59
# ...

# %%
df_2.head()
df_2.tail()
# Out:
#    Crop               Production 2006-07  Production 2007-08  \
# 50    Sweet potato                  81.1                79.3
# 51             Onion               240.5               247.3
# 52          Banana                 189.3               201.1
# 53         Sugarcane               149.8               146.7
# 54           Tobacco                88.1                83.6
#
#     Production 2008-09  Production 2009-10  Production 2010-11  Area 2006-07  \
# 50                94.2                92.1                88.1          75.8
# 51               367.1               329.1               409.1         207.7
# 52               298.8               301.7               339.4         117.6
# 53               120.1               123.2               144.3         142.6
# 54                96.4               105.3               140.9          88.8
#
#     Area 2007-08  Area 2008-09  Area 2009-10  Area 2010-11  Yield 2006-07  \
# ...

# %%
df_3.head()
df_3.tail()
# Out:
#            Crop            Variety Season/ duration in days  \
# 73        Mesta   SHRESTHA (JRM-5)                        -
# 74       Cotton             CNH012                      165
# 75       Cotton  CICR-3 (CISA 614)                      150
# 76       Cotton          VBCH 2231                      150
# 77  Desi Cotton            FDK 124                      150
#
#                                      Recommended Zone
# 73  Andhra Pradesh, Orissa, Assam, Maharashtra, Bi...
# 74           Gujarat, Maharashtra and Madhya Pradesh.
# 75  Punjab, Haryana and Uttar Pradesh under wilt f...
# 76  Maharashtra, Gujarat, Madhya Pradesh and Oriss...
# 77  Punjab, Haryana and Rajasthan under irrigated ...

# %%
df_4.head()
df_4.tail()
# Out:
#                                            Particulars  \
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency   Unit   3-1993   3-1994   3-1995  \
# 424  Annual, Ending mar Of Each Year  kg/ha      0.0      0.0      0.0
# 425  Annual, Ending mar Of Each Year  kg/ha      0.0      0.0      0.0
# 426  Annual, Ending mar Of Each Year  kg/ha      0.0      0.0      0.0
# 427  Annual, Ending mar Of Each Year  kg/ha      0.0      0.0      0.0
# 428  Annual, Ending mar Of Each Year  kg/ha      0.0      0.0      0.0
#
#       3-1996   3-1997   3-1998   3-1999  ...   3-2005   3-2006   3-2007  \
# 424      0.0      0.0      0.1      0.0  ...    778.0    669.0    807.0
# ...

# %% [markdown]
# glob function

# %%
data_files = sorted(glob('datafile_*.csv'))
data_files
# Out:
# ['datafile_0.csv',
#  'datafile_1.csv',
#  'datafile_2.csv',
#  'datafile_3.csv',
#  'datafile_4.csv']

# %%
mergedata=pd.concat(pd.read_csv(datafile).assign(sourcefilename=datafile)for datafile in data_files)
mergedata
# Out:
#                Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0              Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1             Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2    Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3            Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4       Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
# ..              ...      ...      ...      ...      ...      ...      ...
# 424             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 425             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 426             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 427             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 428             NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      2010-11  2011-12  sourcefilename  ...  3-2005   3-2006   3-2007   3-2008  \
# ...

# %% [markdown]
# save to merged file

# %%
mergedata.to_csv('merged.csv')

# %%
mr=pd.read_csv("merged.csv")
mr
# Out:
#      Unnamed: 0            Crop  2004-05  2005-06  2006-07  2007-08  2008-09  \
# 0             0            Rice    100.0    101.0     99.0    105.0    112.0
# 1             1           Wheat    100.0    101.0    112.0    115.0    117.0
# 2             2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0
# 3             3          Pulses    100.0    108.0    134.0    124.0    124.0
# 4             4     Vegetables     100.0    109.0    103.0    118.0    113.0
# ..          ...             ...      ...      ...      ...      ...      ...
# 619         424             NaN      NaN      NaN      NaN      NaN      NaN
# 620         425             NaN      NaN      NaN      NaN      NaN      NaN
# 621         426             NaN      NaN      NaN      NaN      NaN      NaN
# 622         427             NaN      NaN      NaN      NaN      NaN      NaN
# 623         428             NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
mr.isnull().sum()
# Out:
# Unnamed: 0      0
# Crop          485
# 2004-05       612
# 2005-06       612
# 2006-07       612
#              ...
#  3-2010       221
#  3-2011       220
#  3-2012       236
#  3-2013       326
#  3-2014       561
# Length: 61, dtype: int64

# %%
mr.isnull().any()
# Out:
# Unnamed: 0    False
# Crop           True
# 2004-05        True
# 2005-06        True
# 2006-07        True
#               ...
#  3-2010        True
#  3-2011        True
#  3-2012        True
#  3-2013        True
#  3-2014        True
# Length: 61, dtype: bool

# %%
mr.dropna(how='all')
# Out:
#      Unnamed: 0            Crop  2004-05  2005-06  2006-07  2007-08  2008-09  \
# 0             0            Rice    100.0    101.0     99.0    105.0    112.0
# 1             1           Wheat    100.0    101.0    112.0    115.0    117.0
# 2             2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0
# 3             3          Pulses    100.0    108.0    134.0    124.0    124.0
# 4             4     Vegetables     100.0    109.0    103.0    118.0    113.0
# ..          ...             ...      ...      ...      ...      ...      ...
# 619         424             NaN      NaN      NaN      NaN      NaN      NaN
# 620         425             NaN      NaN      NaN      NaN      NaN      NaN
# 621         426             NaN      NaN      NaN      NaN      NaN      NaN
# 622         427             NaN      NaN      NaN      NaN      NaN      NaN
# 623         428             NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
mr=mr.fillna(method='ffill')
mr
# Out:
#      Unnamed: 0            Crop  2004-05  2005-06  2006-07  2007-08  2008-09  \
# 0             0            Rice    100.0    101.0     99.0    105.0    112.0
# 1             1           Wheat    100.0    101.0    112.0    115.0    117.0
# 2             2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0
# 3             3          Pulses    100.0    108.0    134.0    124.0    124.0
# 4             4     Vegetables     100.0    109.0    103.0    118.0    113.0
# ..          ...             ...      ...      ...      ...      ...      ...
# 619         424     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 620         425     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 621         426     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 622         427     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 623         428     Desi Cotton    100.0     99.0    101.0    104.0    106.0
#
# ...

# %%
mr=mr.fillna(method='bfill')
mr
# Out:
#      Unnamed: 0            Crop  2004-05  2005-06  2006-07  2007-08  2008-09  \
# 0             0            Rice    100.0    101.0     99.0    105.0    112.0
# 1             1           Wheat    100.0    101.0    112.0    115.0    117.0
# 2             2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0
# 3             3          Pulses    100.0    108.0    134.0    124.0    124.0
# 4             4     Vegetables     100.0    109.0    103.0    118.0    113.0
# ..          ...             ...      ...      ...      ...      ...      ...
# 619         424     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 620         425     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 621         426     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 622         427     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 623         428     Desi Cotton    100.0     99.0    101.0    104.0    106.0
#
# ...

# %%
mr=mr.interpolate()
mr
# Out:
#      Unnamed: 0            Crop  2004-05  2005-06  2006-07  2007-08  2008-09  \
# 0             0            Rice    100.0    101.0     99.0    105.0    112.0
# 1             1           Wheat    100.0    101.0    112.0    115.0    117.0
# 2             2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0
# 3             3          Pulses    100.0    108.0    134.0    124.0    124.0
# 4             4     Vegetables     100.0    109.0    103.0    118.0    113.0
# ..          ...             ...      ...      ...      ...      ...      ...
# 619         424     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 620         425     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 621         426     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 622         427     Desi Cotton    100.0     99.0    101.0    104.0    106.0
# 623         428     Desi Cotton    100.0     99.0    101.0    104.0    106.0
#
# ...

# %%
mr.isnull().sum()
# Out:
# Unnamed: 0    0
# Crop          0
# 2004-05       0
# 2005-06       0
# 2006-07       0
#              ..
#  3-2010       0
#  3-2011       0
#  3-2012       0
#  3-2013       0
#  3-2014       0
# Length: 61, dtype: int64

# %%
mr = mr.drop('Unnamed: 0', axis=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = mr[['Yield (Quintal/ Hectare) ','Cost of Cultivation (`/Hectare) A2+FL', 'Cost of Cultivation (`/Hectare) C2']]
Y = mr['Production 2006-07']

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, Y_train)

# Make predictions on the testing set
Y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
rmse = mse**0.5
print("Root Mean Squared Error:", rmse)

# Use the model to make predictions on new data
a = input("Enter the State\n")
b = input("Enter the cultivation cost per hectare\n")
c = input("Enter the cultivation cost per hectare in c2\n")
new_data = pd.DataFrame({'Yield (Quintal/ Hectare) ': [a], 'Cost of Cultivation (`/Hectare) A2+FL': [b], 'Cost of Cultivation (`/Hectare) C2': [c]})
areaYield = model.predict(new_data)
print("the crop rate in 2010-11 is", areaYield)
# Out:
# Root Mean Squared Error: 26.388081594294466
# Enter the State
# 58
# Enter the cultivation cost per hectare
# 40000
# Enter the cultivation cost per hectare in c2
# 45000
# the crop rate in 2010-11 is [23.90418582]
